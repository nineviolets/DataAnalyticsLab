# %% [markdown]
# <a href="https://colab.research.google.com/github/nineviolets/DataAnalyticsLab/blob/master/Decision_tree_classification_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A decision tree is a class discriminator that recursively partitions the training set until each partition consists entirely or dominantly of examples from one class.
#
# A decision tree is a structure that includes a root node, branches, and leaf nodes. Each internal node denotes a test on an attribute, each branch denotes the outcome of a test, and each leaf node holds a class label. The topmost node in the tree is the root node.
#
# example age->young and middle age and senior and -> young->student, middleage->yes, senior-> credit_rating...
# no yes leave nodes for all the branch nodes
#
# Each non-leaf node of the tree contains a split point that is a test on one or more attributes and determines how the data is partitioned.

# %% [markdown]
# ***Implement a Simple Decision Tree Classifier using Scikit Learn***

# %% [markdown]
# Importing required laibraries and datasets

# %%
import pandas as pd
import numpy as np
from sklearn. datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
data=load_iris()
print('Classes to predict:',data.target_names)
# Out:
# Classes to predict: ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# ***Storing the dependant and independent attributes in seperate variables ***

# %%
X=data.data
y=data.target
print("Number of records in dataset:",X.shape[0])
print(X[:4])
# Out:
# Number of records in dataset: 150
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]]

# %% [markdown]
# **Splitting training and test dataset seperately**

# %%
X_train,X_test,y_train, y_test=train_test_split(X,y,random_state=22, test_size=0.45)

# %% [markdown]
# ***Initializing the DecisionTreeClassifier with entropy as splitting metrics***

# %%
clf=DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score on train data',accuracy_score
      (y_true=y_train,y_pred=clf.predict(X_train)))
print('Accuracy score on test data',accuracy_score
      (y_true=y_test,y_pred=y_pred))
# Out:
# Accuracy score on train data 1.0
# Accuracy score on test data 0.9264705882352942

# %% [markdown]
# **Printing the Decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt
plt.figure(figsize = (20,20))
plot_tree(clf,filled=True)
plt.show()
